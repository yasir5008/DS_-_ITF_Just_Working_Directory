# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
 # !pip install squarify

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from plotly.offline import init_notebook_mode,iplot
import squarify

import warnings                      
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook   bu notebook zorlar ancak interaktif olarak imkan sağlar.

plt.rcParams["figure.figsize"] = (10,6)   # tüm grafikleri bu ölcüye sabitledik.
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")             # çizime özel yapılabilsede gridleri beyaz yaptı.
pd.set_option('display.float_format', lambda x: '%.3f' % x)   # tüm floatları virgülden sonra 3 karakter verir.

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Clarusway - ML2/1- Projects/Capstone Projects/1_C9_DS_Capstone_Projects_(Customer_Segmentation)/Online Retail.xlsx'

# %%
# path = "Online Retail.xlsx"

# %%
df1 = pd.read_excel(path, 
                   dtype={"InvoiceNo":str,"StockCode":str, "CustomerID": str},
                   parse_dates=['InvoiceDate'])

# %%
df = df1.copy()
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0  536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1  536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2  536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3  536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4  536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00      2.550    17850.0  United Kingdom
# 1 2010-12-01 08:26:00      3.390    17850.0  United Kingdom
# 2 2010-12-01 08:26:00      2.750    17850.0  United Kingdom
# 3 2010-12-01 08:26:00      3.390    17850.0  United Kingdom
# 4 2010-12-01 08:26:00      3.390    17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 33.1+ MB

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.describe(include= "all").T
# Out:
#                  count unique                                 top    freq  \
# InvoiceNo       541909  25900                            573585.0    1114
# StockCode       541909   4070                              85123A    2313
# Description     540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Quantity    541909.000    NaN                                 NaN     NaN
# InvoiceDate     541909  23260                 2011-10-31 14:41:00    1114
# UnitPrice   541909.000    NaN                                 NaN     NaN
# CustomerID      406829   4372                             17841.0    7983
# Country         541909     38                      United Kingdom  495478
#
#                           first                last  mean     std        min  \
# InvoiceNo                   NaT                 NaT   NaN     NaN        NaN
# StockCode                   NaT                 NaT   NaN     NaN        NaN
# ...

# %%
df.describe().T
# Out:
#                count  mean     std        min   25%   50%    75%       max
# Quantity  541909.000 9.552 218.081 -80995.000 1.000 3.000 10.000 80995.000
# UnitPrice 541909.000 4.611  96.760 -11062.060 1.250 2.080  4.130 38970.000

# %%
df.skew()
# Out:
# Quantity      -0.264
# UnitPrice    186.507
# CustomerID     0.030
# dtype: float64

# %%
df.kurtosis()
# Out:
# Quantity     119769.160
# UnitPrice     59005.719
# CustomerID       -1.180
# dtype: float64

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# InvoiceNo      0.000
# StockCode      0.000
# Description    0.268
# Quantity       0.000
# InvoiceDate    0.000
# UnitPrice      0.000
# CustomerID    24.927
# Country        0.000
# dtype: float64

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df[['InvoiceNo', 'Quantity', 'UnitPrice']].head()
# Out:
#   InvoiceNo  Quantity  UnitPrice
# 0  536365.0     6.000      2.550
# 1  536365.0     6.000      3.390
# 2  536365.0     8.000      2.750
# 3  536365.0     6.000      3.390
# 4  536365.0     6.000      3.390

# %%
df[['InvoiceNo', 'Quantity', 'UnitPrice']].describe()
# Out:
#         Quantity  UnitPrice
# count 541909.000 541909.000
# mean       9.552      4.611
# std      218.081     96.760
# min   -80995.000 -11062.060
# 25%        1.000      1.250
# 50%        3.000      2.080
# 75%       10.000      4.130
# max    80995.000  38970.000

# %%
df['InvoiceNo'].nunique()
# Out:
# 25900

# %%
df.groupby('InvoiceNo')[['Quantity', 'UnitPrice']].count()
# Out:
#            Quantity  UnitPrice
# InvoiceNo
# 536365.0          7          7
# 536366.0          2          2
# 536367.0         12         12
# 536368.0          4          4
# 536369.0          1          1
# ...             ...        ...
# C581484           1          1
# C581490           2          2
# C581499           1          1
# C581568           1          1
# C581569           2          2
#
# [25900 rows x 2 columns]

# %%
df.groupby('InvoiceNo').agg({'Quantity':sum, 'UnitPrice':sum})
# Out:
#             Quantity  UnitPrice
# InvoiceNo
# 536365.0      40.000     27.370
# 536366.0      12.000      3.700
# 536367.0      83.000     58.240
# 536368.0      15.000     19.100
# 536369.0       3.000      5.950
# ...              ...        ...
# C581484   -80995.000      2.080
# C581490      -23.000      2.780
# C581499       -1.000    224.690
# C581568       -5.000     10.950
# C581569       -6.000      2.500
#
# [25900 rows x 2 columns]

# %%
df.groupby('InvoiceNo').agg({'Quantity':np.mean, 'UnitPrice':np.mean})
# Out:
#             Quantity  UnitPrice
# InvoiceNo
# 536365.0       5.714      3.910
# 536366.0       6.000      1.850
# 536367.0       6.917      4.853
# 536368.0       3.750      4.775
# 536369.0       3.000      5.950
# ...              ...        ...
# C581484   -80995.000      2.080
# C581490      -11.500      1.390
# C581499       -1.000    224.690
# C581568       -5.000     10.950
# C581569       -3.000      1.250
#
# [25900 rows x 2 columns]

# %%
print("Summary..")
#exploring the unique values of each attribute
print("Number of transactions: ", df['InvoiceNo'].nunique())
print("Number of products bought: ", df['StockCode'].nunique())
print("Number of customers:", df['CustomerID'].nunique() )
print("Percentage of customers NA: ", round(df['CustomerID'].isnull().sum() * 100 / len(df),2),"%" )
# Out:
# Summary..
# Number of transactions:  25900
# Number of products bought:  4070
# Number of customers: 4372
# Percentage of customers NA:  24.93 %

# %% [raw]
# pd.DataFrame([{'products': len(df['StockCode'].value_counts()),
#                'transactions': len(df['InvoiceNo'].value_counts()),
#                'customers': len(df['CustomerID'].value_counts()),
#               }], columns = ['customers','products', 'transactions'], index = ['quantity'])

# %% [markdown]
# In summary; as can be seen above, we can say that 25900 transactions were made for 3684 products by 4372 customers.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[df.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         UnitPrice CustomerID         Country
# 299983 -11062.060        NaN  United Kingdom
# 299984 -11062.060        NaN  United Kingdom

# %%
df[df.Quantity<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 541541   C581499         M                            Manual    -1.000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE    -5.000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df.InvoiceNo.str.startswith('C').value_counts()
# Out:
# False    532621
# True       9288
# Name: InvoiceNo, dtype: int64

# %%
df[df.InvoiceNo.str.startswith('C')]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 541541   C581499         M                            Manual    -1.000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE    -5.000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
df[df['CustomerID'] == '12346.0']
# Out:
#       InvoiceNo StockCode                     Description   Quantity  \
# 61619  541431.0   23166.0  MEDIUM CERAMIC TOP STORAGE JAR  74215.000
# 61624   C541433   23166.0  MEDIUM CERAMIC TOP STORAGE JAR -74215.000
#
#               InvoiceDate  UnitPrice CustomerID         Country
# 61619 2011-01-18 10:01:00      1.040    12346.0  United Kingdom
# 61624 2011-01-18 10:17:00      1.040    12346.0  United Kingdom

# %% [markdown]
# By looking at these results, it appears that there is a counterpart to the canceled transaction.
#
# Product owner should decide to keep or to remove the positive values as sold items. In reality, they are returned and may not be analized as sold. We choose to keep them in our data.

# %%
df[df.CustomerID=="17548.0"]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 235      C536391   22556.0     PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391   21984.0   PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391   21983.0   PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# 238      C536391   21980.0  PACK OF 12 RED RETROSPOT TISSUES    -24.000
# 239      C536391   21484.0        CHICK GREY HOT WATER BOTTLE   -12.000
# 240      C536391   22557.0   PLASTERS IN TIN VINTAGE PAISLEY    -12.000
# 241      C536391   22553.0             PLASTERS IN TIN SKULLS   -24.000
# 165024  550755.0   22585.0          PACK OF 6 BIRDY GIFT TAGS    24.000
# 165025  550755.0   22082.0        RIBBON REEL STRIPES DESIGN     10.000
# 165026  550755.0   22081.0         RIBBON REEL FLORA + FAUNA     10.000
# 165027  550755.0   22079.0         RIBBON REEL HEARTS DESIGN     10.000
# 165028  550755.0   22926.0     IVORY GIANT GARDEN THERMOMETER     4.000
# ...

# %% [markdown]
# Here, we see that some transactions are canceled with C after the order, but some of the canceled part does not have the entry part. Because the entry date coincides with the first start date of df. Again, we see that some of the canceled orders are partial.

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
df[(df['Quantity'] < 0) & (df['InvoiceNo'].str.contains('C'))]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391   22556.0    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391   21984.0  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391   21983.0  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 540449   C581490   23144.0   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 541541   C581499         M                            Manual    -1.000
# 541715   C581568   21258.0        VICTORIAN SEWING BOX LARGE    -5.000
# 541716   C581569   84978.0  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 541717   C581569   20979.0     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
df[(df['Quantity'] < 0) & (~df['InvoiceNo'].str.contains('C'))]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2406    536589.0   21777.0         NaN   -10.000 2010-12-01 16:50:00
# 4347    536764.0    84952C         NaN   -38.000 2010-12-02 14:42:00
# 7188    536996.0   22712.0         NaN   -20.000 2010-12-03 15:30:00
# 7189    536997.0   22028.0         NaN   -20.000 2010-12-03 15:30:00
# 7190    536998.0   85067.0         NaN    -6.000 2010-12-03 15:30:00
# ...          ...       ...         ...       ...                 ...
# 535333  581210.0   23395.0       check   -26.000 2011-12-07 18:36:00
# 535335  581212.0   22578.0        lost -1050.000 2011-12-07 18:38:00
# 535336  581213.0   22576.0       check   -30.000 2011-12-07 18:38:00
# 536908  581226.0   23090.0     missing  -338.000 2011-12-08 09:56:00
# 538919  581422.0   23169.0     smashed  -235.000 2011-12-08 15:24:00
#
#         UnitPrice CustomerID         Country
# 2406        0.000        NaN  United Kingdom
# 4347        0.000        NaN  United Kingdom
# ...

# %%
df[(df['Quantity'] > 0) & (df['InvoiceNo'].str.contains('C'))]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# Above:
# - the number of those with both InvoiceNo C and Quantity < 0 is 9288 (the number that was canceled from the 25900 invoice),
# the number of those with Quantity < 0 without InvoiceNo C is 1336,
# - We found the number of those with InvoiceNo C and Quantity > 0 as 0.

# %% [markdown]
# 9288 or about 36% of the orders were cancelled. Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df.loc[df.UnitPrice <0,["InvoiceNo","Description", "UnitPrice", "Quantity"]]
# Out:
#        InvoiceNo      Description  UnitPrice  Quantity
# 299983   A563186  Adjust bad debt -11062.060     1.000
# 299984   A563187  Adjust bad debt -11062.060     1.000

# %%
df.loc[df.InvoiceNo.str.startswith("A"), ["InvoiceNo","Description", "UnitPrice", "Quantity"]]
# Out:
#        InvoiceNo      Description  UnitPrice  Quantity
# 299982   A563185  Adjust bad debt  11062.060     1.000
# 299983   A563186  Adjust bad debt -11062.060     1.000
# 299984   A563187  Adjust bad debt -11062.060     1.000

# %% [markdown]
# ### iii. Handling Missing Values

# %%
df[(df['UnitPrice'] < 0) & ~(df['InvoiceNo'].str.contains('C'))]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         UnitPrice CustomerID         Country
# 299983 -11062.060        NaN  United Kingdom
# 299984 -11062.060        NaN  United Kingdom

# %%
df[(df['Quantity'] < 0) & (df['InvoiceNo'].str.contains('C'))]['CustomerID'].value_counts(dropna=False)
# Out:
# NaN        383
# 14911.0    226
# 17841.0    136
# 17511.0    113
# 15311.0    112
#           ...
# 13199.0      1
# 15400.0      1
# 16814.0      1
# 13632.0      1
# 16446.0      1
# Name: CustomerID, Length: 1590, dtype: int64

# %%
df[(df['Quantity'] < 0) & ~(df['InvoiceNo'].str.contains('C'))]['CustomerID'].value_counts(dropna=False)
# Out:
# NaN    1336
# Name: CustomerID, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 33.1+ MB

# %%
df['CustomerID'].value_counts(dropna = False)
# Out:
# NaN        135080
# 17841.0      7983
# 14911.0      5903
# 14096.0      5128
# 12748.0      4642
#             ...
# 13270.0         1
# 17763.0         1
# 17291.0         1
# 15668.0         1
# 15562.0         1
# Name: CustomerID, Length: 4373, dtype: int64

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
plt.figure(figsize=(5, 5))
df.isnull().mean(axis=0).plot.barh()
plt.title("Ratio of missing values per columns")
# Out:
# Text(0.5, 1.0, 'Ratio of missing values per columns')

# %%
print('Dupplicate entries: {}'.format(df.duplicated().sum()))
# df.drop_duplicates(inplace = True)
# Out:
# Dupplicate entries: 5225

# %%
df.drop_duplicates(inplace = True)

# %%
df.describe()
# Out:
#         Quantity  UnitPrice
# count 401604.000 401604.000
# mean      12.183      3.474
# std      250.283     69.764
# min   -80995.000      0.000
# 25%        2.000      1.250
# 50%        5.000      1.950
# 75%       12.000      3.750
# max    80995.000  38970.000

# %%
df = df[df.UnitPrice>0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401564 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401564 non-null  object
#  1   StockCode    401564 non-null  object
#  2   Description  401564 non-null  object
#  3   Quantity     401564 non-null  float64
#  4   InvoiceDate  401564 non-null  datetime64[ns]
#  5   UnitPrice    401564 non-null  float64
#  6   CustomerID   401564 non-null  object
#  7   Country      401564 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 27.6+ MB

# %% [markdown]
# These are specific operations which doesn't characterize our customers so I'll just drop these transactions.

# %%
df[df['StockCode'].str.contains('^[a-zA-Z]+', regex=True)]['StockCode'].unique()
# Out:
# array(['POST', 'D', 'C2', 'M', 'BANK CHARGES', 'PADS', 'DOT', 'CRUK'],
#       dtype=object)

# %%
df = df[df['StockCode']!= 'POST']
df = df[df['StockCode']!= 'D']
df = df[df['StockCode']!= 'C2']
df = df[df['StockCode']!= 'M']
df = df[df['StockCode']!= 'BANK CHARGES']
df = df[df['StockCode']!= 'PADS']
df = df[df['StockCode']!= 'DOT']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 399672 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    399672 non-null  object
#  1   StockCode    399672 non-null  object
#  2   Description  399672 non-null  object
#  3   Quantity     399672 non-null  float64
#  4   InvoiceDate  399672 non-null  datetime64[ns]
#  5   UnitPrice    399672 non-null  float64
#  6   CustomerID   399672 non-null  object
#  7   Country      399672 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 27.4+ MB

# %%
df.dropna(subset = ['CustomerID'], inplace=True)   # we should drop Na after dropping duplicates.

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby('CustomerID')[['InvoiceNo']].nunique()
# Out:
#             InvoiceNo
# CustomerID
# 12346.0             2
# 12347.0             7
# 12348.0             4
# 12349.0             1
# 12350.0             1
# ...               ...
# 18280.0             1
# 18281.0             1
# 18282.0             3
# 18283.0            16
# 18287.0             3
#
# [4362 rows x 1 columns]

# %%
df.groupby('CustomerID')[['InvoiceNo']].count().sort_values('CustomerID', ascending=True)

# df.groupby('CustomerID')['InvoiceNo'].aggregate("count").reset_index().sort_values('CustomerID', ascending=True)
# Out:
#             InvoiceNo
# CustomerID
# 12346.0             2
# 12347.0           182
# 12348.0            27
# 12349.0            72
# 12350.0            16
# ...               ...
# 18280.0            10
# 18281.0             7
# 18282.0            13
# 18283.0           719
# 18287.0            70
#
# [4362 rows x 1 columns]

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.groupby('CustomerID')[['StockCode']].nunique()   #sort this for a good display to product owner
# Out:
#             StockCode
# CustomerID
# 12346.0             1
# 12347.0           103
# 12348.0            21
# 12349.0            72
# 12350.0            16
# ...               ...
# 18280.0            10
# 18281.0             7
# 18282.0            12
# 18283.0           262
# 18287.0            59
#
# [4362 rows x 1 columns]

# %%
df.groupby('CustomerID')[['StockCode']].nunique().mean()
# Out:
# StockCode   61.185
# dtype: float64

# %%
df.groupby('InvoiceNo').nunique()[['StockCode']].mean()
# Out:
# StockCode   18.110
# dtype: float64

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby('CustomerID')[['StockCode']].nunique()
# Out:
#             StockCode
# CustomerID
# 12346.0             1
# 12347.0           103
# 12348.0            21
# 12349.0            72
# 12350.0            16
# ...               ...
# 18280.0            10
# 18281.0             7
# 18282.0            12
# 18283.0           262
# 18287.0            59
#
# [4362 rows x 1 columns]

# %%
def unique_counts(df):
   for i in df.columns:
       count = df[i].nunique()
       print(f"{i:<15} : {count}")
unique_counts(df)
# Out:
# InvoiceNo       : 21801
# StockCode       : 3677
# Description     : 3889
# Quantity        : 431
# InvoiceDate     : 20132
# UnitPrice       : 387
# CustomerID      : 4362
# Country         : 37

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df['TotalPrice'] = df['UnitPrice'] * df['Quantity']

# %%
df.groupby('Country')[['TotalPrice']].sum().reset_index().sort_values('TotalPrice', ascending=False)
# Out:
#                  Country  TotalPrice
# 35        United Kingdom 6794612.150
# 23           Netherlands  283479.540
# 10                  EIRE  246732.470
# 14               Germany  200619.660
# 13                France  181385.540
# 0              Australia  136922.500
# 32           Switzerland   51859.400
# 30                 Spain   51746.650
# 3                Belgium   36662.960
# 19                 Japan   35419.790
# 31                Sweden   35166.410
# 24                Norway   32292.960
# 26              Portugal   26500.260
# 6        Channel Islands   19926.390
# 12               Finland   18303.540
# 9                Denmark   18042.140
# 18                 Italy   15276.340
# 7                 Cyprus   12843.760
# 29             Singapore    9120.390
# 1                Austria    8698.320
# 17                Israel    6988.400
# 25                Poland    6853.140
# 15                Greece    4425.520
# 16               Iceland    4310.000
# ...

# %% [markdown]
# 2. Visualize number of customer per country

# %%
df.groupby('Country')[['CustomerID']].count().reset_index().sort_values('CustomerID', ascending=False)
# Out:
#                  Country  CustomerID
# 35        United Kingdom      356106
# 14               Germany        9080
# 13                France        8152
# 10                  EIRE        7368
# 30                 Spain        2462
# 23           Netherlands        2326
# 3                Belgium        1971
# 32           Switzerland        1843
# 26              Portugal        1427
# 0              Australia        1253
# 24                Norway        1059
# 18                 Italy         783
# 6        Channel Islands         752
# 12               Finland         653
# 7                 Cyprus         608
# 31                Sweden         436
# 1                Austria         387
# 9                Denmark         375
# 19                 Japan         355
# 25                Poland         336
# 33                   USA         291
# 17                Israel         247
# 36           Unspecified         241
# 29             Singapore         215
# ...

# %%
df.groupby('Country')[['CustomerID']].count().sort_values('CustomerID', ascending=False).plot.bar()

# %% [markdown]
# 3. Visualize total cost per country

# %%
df.groupby('Country')[['TotalPrice']].sum().reset_index().sort_values('TotalPrice', ascending=False).plot.bar()

# %%
temp = df[['CustomerID', 'InvoiceNo', 'Country']].groupby(['CustomerID', 'InvoiceNo', 'Country']).count()
temp = temp.reset_index(drop = False)
countries = temp['Country'].value_counts()
print('Number of countries in Dataframe: {}'.format(len(countries)))
# Out:
# Number of countries in Dataframe: 37

# %%
# data = dict(type='choropleth',
# locations = countries.index,
# locationmode = 'country names', z = countries,
# text = countries.index, colorbar = {'title':'Order nb.'},
# colorscale=[[0, 'rgb(224,255,255)'],
#             [0.01, 'rgb(166,206,227)'], [0.02, 'rgb(31,120,180)'],
#             [0.03, 'rgb(178,223,138)'], [0.05, 'rgb(51,160,44)'],
#             [0.10, 'rgb(251,154,153)'], [0.20, 'rgb(255,255,0)'],
#             [1, 'rgb(227,26,28)']],    
# reversescale = False)
# #_______________________
# layout = dict(title='Number of orders per country',
# geo = dict(showframe = True, projection={'type':'mercator'}))
# #______________
# choromap = geo.Figure(data = [data], layout = layout)
# iplot(choromap, validate=False)

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk_or = df[df.Country == 'United Kingdom']
df_uk = df_uk_or.copy()
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                InvoiceDate  UnitPrice CustomerID         Country  TotalPrice
# ...

# %%
df_uk.drop("Country", axis = 1, inplace = True)

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 356106 entries, 0 to 541893
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    356106 non-null  object
#  1   StockCode    356106 non-null  object
#  2   Description  356106 non-null  object
#  3   Quantity     356106 non-null  float64
#  4   InvoiceDate  356106 non-null  datetime64[ns]
#  5   UnitPrice    356106 non-null  float64
#  6   CustomerID   356106 non-null  object
#  7   TotalPrice   356106 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 24.5+ MB

# %%
df_uk= df_uk[df_uk.Quantity>0]

# %%
df_uk.describe().T
# Out:
#                 count   mean     std   min   25%    50%    75%        max
# Quantity   348872.000 12.137 190.677 1.000 2.000  4.000 12.000  80995.000
# UnitPrice  348872.000  2.864   4.341 0.040 1.250  1.950  3.750    649.500
# TotalPrice 348872.000 20.761 328.109 0.060 4.200 10.200 17.850 168469.600

# %%
def unique_counts(df):
   for i in df.columns:
       count = df[i].nunique()
       print(f"{i:<15} : {count}")
unique_counts(df_uk)
# Out:
# InvoiceNo       : 16579
# StockCode       : 3639
# Description     : 3838
# Quantity        : 291
# InvoiceDate     : 15555
# UnitPrice       : 354
# CustomerID      : 3916
# TotalPrice      : 2743

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby(["StockCode","Description"])[["Quantity"]].sum().sort_values("Quantity", ascending=False).head(3)
# Out:
#                                              Quantity
# StockCode Description
# 23843.0   PAPER CRAFT , LITTLE BIRDIE       80995.000
# 23166.0   MEDIUM CERAMIC TOP STORAGE JAR    76919.000
# 84077.0   WORLD WAR 2 GLIDERS ASSTD DESIGNS 49086.000

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %% [markdown]
# Since the features we need in RFM analysis; InvoiceNo, InvoiceDate, CustomerID and Total we will drop the other features.

# %%
df_uk['InvoiceDate'].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
df_uk['InvoiceDate'].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %%
df_uknew = df_uk.drop(["StockCode", "Description", "Quantity", "UnitPrice"], axis = 1)

# %%
df_uknew.head()
# Out:
#   InvoiceNo         InvoiceDate CustomerID  TotalPrice
# 0  536365.0 2010-12-01 08:26:00    17850.0      15.300
# 1  536365.0 2010-12-01 08:26:00    17850.0      20.340
# 2  536365.0 2010-12-01 08:26:00    17850.0      22.000
# 3  536365.0 2010-12-01 08:26:00    17850.0      20.340
# 4  536365.0 2010-12-01 08:26:00    17850.0      20.340

# %%
df_uknew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348872 entries, 0 to 541893
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    348872 non-null  object
#  1   InvoiceDate  348872 non-null  datetime64[ns]
#  2   CustomerID   348872 non-null  object
#  3   TotalPrice   348872 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 13.3+ MB

# %%
df_uknew.describe().T
# Out:
#                 count   mean     std   min   25%    50%    75%        max
# TotalPrice 348872.000 20.761 328.109 0.060 4.200 10.200 17.850 168469.600

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
# ref_date = dt.datetime(2011, 12, 11)
# I'll just fix the date to be one day after the last entry in the databse and called it ref_date.

# %%
df_uknew.groupby(['InvoiceNo', 'InvoiceDate']).agg({'CustomerID' : min, 'TotalPrice' : sum})
# Out:
#                               CustomerID  TotalPrice
# InvoiceNo InvoiceDate
# 536365.0  2010-12-01 08:26:00    17850.0     139.120
# 536366.0  2010-12-01 08:28:00    17850.0      22.200
# 536367.0  2010-12-01 08:34:00    13047.0     278.730
# 536368.0  2010-12-01 08:34:00    13047.0      70.050
# 536369.0  2010-12-01 08:35:00    13047.0      17.850
# ...                                  ...         ...
# 581582.0  2011-12-09 12:21:00    17581.0      29.880
# 581583.0  2011-12-09 12:23:00    13777.0     124.600
# 581584.0  2011-12-09 12:25:00    13777.0     140.640
# 581585.0  2011-12-09 12:31:00    15804.0     329.050
# 581586.0  2011-12-09 12:49:00    13113.0     339.200
#
# [16606 rows x 2 columns]

# %%
df_uknew["Ref_Date"] = df_uknew.InvoiceDate.max() + dt.timedelta(days = 2)
df_uknew["Ref_Date"] = df_uknew["Ref_Date"].dt.date

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uknew["InvoiceDate"] = df_uknew.InvoiceDate.dt.date

# %%
# df_uknew.drop(["InvoiceDate"], axis = 1, inplace = True)
df_uknew
# Out:
#        InvoiceNo InvoiceDate CustomerID  TotalPrice    Ref_Date
# 0       536365.0  2010-12-01    17850.0      15.300  2011-12-11
# 1       536365.0  2010-12-01    17850.0      20.340  2011-12-11
# 2       536365.0  2010-12-01    17850.0      22.000  2011-12-11
# 3       536365.0  2010-12-01    17850.0      20.340  2011-12-11
# 4       536365.0  2010-12-01    17850.0      20.340  2011-12-11
# ...          ...         ...        ...         ...         ...
# 541889  581585.0  2011-12-09    15804.0      23.400  2011-12-11
# 541890  581586.0  2011-12-09    13113.0      23.600  2011-12-11
# 541891  581586.0  2011-12-09    13113.0      30.000  2011-12-11
# 541892  581586.0  2011-12-09    13113.0     214.800  2011-12-11
# 541893  581586.0  2011-12-09    13113.0      70.800  2011-12-11
#
# [348872 rows x 5 columns]

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_uknew.groupby("CustomerID").agg({"InvoiceDate": max})

# df_uknew.groupby("CustomerID")[["Date"]].max()
# Out:
#            InvoiceDate
# CustomerID
# 12346.0     2011-01-18
# 12747.0     2011-12-07
# 12748.0     2011-12-09
# 12749.0     2011-12-06
# 12820.0     2011-12-06
# ...                ...
# 18280.0     2011-03-07
# 18281.0     2011-06-12
# 18282.0     2011-12-02
# 18283.0     2011-12-06
# 18287.0     2011-10-28
#
# [3916 rows x 1 columns]

# %%
df_uknew.groupby("CustomerID")[["InvoiceDate"]].min()
# Out:
#            InvoiceDate
# CustomerID
# 12346.0     2011-01-18
# 12747.0     2010-12-05
# 12748.0     2010-12-01
# 12749.0     2011-05-10
# 12820.0     2011-01-17
# ...                ...
# 18280.0     2011-03-07
# 18281.0     2011-06-12
# 18282.0     2011-08-05
# 18283.0     2011-01-06
# 18287.0     2011-05-22
#
# [3916 rows x 1 columns]

# %%
df_uknew.groupby('CustomerID')['InvoiceDate'].agg(['first', 'last']).reset_index()
# Out:
#      CustomerID       first        last
# 0       12346.0  2011-01-18  2011-01-18
# 1       12747.0  2010-12-05  2011-12-07
# 2       12748.0  2010-12-01  2011-12-09
# 3       12749.0  2011-05-10  2011-12-06
# 4       12820.0  2011-01-17  2011-12-06
# ...         ...         ...         ...
# 3911    18280.0  2011-03-07  2011-03-07
# 3912    18281.0  2011-06-12  2011-06-12
# 3913    18282.0  2011-08-05  2011-12-02
# 3914    18283.0  2011-01-06  2011-12-06
# 3915    18287.0  2011-05-22  2011-10-28
#
# [3916 rows x 3 columns]

# %% [markdown]
# 4. Calculate the number of days since last purchase

# %%
df_uknew['last_purchase'] = df_uknew["Ref_Date"]-df_uknew["InvoiceDate"]

# %%
df_uknew["last_purchase"] = df_uknew["last_purchase"].astype("str").str.split(" ").str[0].astype(int)

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_uknew1=df_uknew.copy()

# %%
rfmtable = df_uknew1.groupby('CustomerID').agg({'last_purchase' : 'min'}).reset_index().rename(columns={'last_purchase': 'recency'})

# %%
rfmtable
# Out:
#      CustomerID  recency
# 0       12346.0      327
# 1       12747.0        4
# 2       12748.0        2
# 3       12749.0        5
# 4       12820.0        5
# ...         ...      ...
# 3911    18280.0      279
# 3912    18281.0      182
# 3913    18282.0        9
# 3914    18283.0        5
# 3915    18287.0       44
#
# [3916 rows x 2 columns]

# %%
df_uknew1.drop(['InvoiceDate', 'Ref_Date'], axis = 1, inplace = True)

# %%
df_uknew1["CustomerID"].value_counts(dropna=False)
# Out:
# 17841.0    7667
# 14096.0    5095
# 12748.0    4397
# 14606.0    2674
# 15311.0    2366
#            ...
# 13120.0       1
# 17752.0       1
# 16144.0       1
# 13841.0       1
# 17956.0       1
# Name: CustomerID, Length: 3916, dtype: int64

# %% [markdown]
# 6. Plot RFM distributions

# %%
plt.figure(figsize=(12,10))
sns.distplot(rfmtable['recency'])

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uknew
# Out:
#        InvoiceNo InvoiceDate CustomerID  TotalPrice    Ref_Date  last_purchase
# 0       536365.0  2010-12-01    17850.0      15.300  2011-12-11            375
# 1       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# 2       536365.0  2010-12-01    17850.0      22.000  2011-12-11            375
# 3       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# 4       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# ...          ...         ...        ...         ...         ...            ...
# 541889  581585.0  2011-12-09    15804.0      23.400  2011-12-11              2
# 541890  581586.0  2011-12-09    13113.0      23.600  2011-12-11              2
# 541891  581586.0  2011-12-09    13113.0      30.000  2011-12-11              2
# 541892  581586.0  2011-12-09    13113.0     214.800  2011-12-11              2
# 541893  581586.0  2011-12-09    13113.0      70.800  2011-12-11              2
#
# ...

# %%
df_uknew2=df_uknew.copy()

# %%
df_uknew2[df_uknew2.duplicated()==True]
# Out:
#        InvoiceNo InvoiceDate CustomerID  TotalPrice    Ref_Date  last_purchase
# 3       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# 4       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# 8       536366.0  2010-12-01    17850.0      11.100  2011-12-11            375
# 11      536367.0  2010-12-01    13047.0      12.600  2011-12-11            375
# 18      536367.0  2010-12-01    13047.0      17.850  2011-12-11            375
# ...          ...         ...        ...         ...         ...            ...
# 541880  581585.0  2011-12-09    15804.0      15.000  2011-12-11              2
# 541884  581585.0  2011-12-09    15804.0      15.000  2011-12-11              2
# 541886  581585.0  2011-12-09    15804.0       4.680  2011-12-11              2
# 541887  581585.0  2011-12-09    15804.0      15.000  2011-12-11              2
# 541889  581585.0  2011-12-09    15804.0      23.400  2011-12-11              2
#
# ...

# %%
df_uknew2[df_uknew2.duplicated()==False]
# Out:
#        InvoiceNo InvoiceDate CustomerID  TotalPrice    Ref_Date  last_purchase
# 0       536365.0  2010-12-01    17850.0      15.300  2011-12-11            375
# 1       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# 2       536365.0  2010-12-01    17850.0      22.000  2011-12-11            375
# 5       536365.0  2010-12-01    17850.0      15.300  2011-12-11            375
# 6       536365.0  2010-12-01    17850.0      25.500  2011-12-11            375
# ...          ...         ...        ...         ...         ...            ...
# 541888  581585.0  2011-12-09    15804.0      11.400  2011-12-11              2
# 541890  581586.0  2011-12-09    13113.0      23.600  2011-12-11              2
# 541891  581586.0  2011-12-09    13113.0      30.000  2011-12-11              2
# 541892  581586.0  2011-12-09    13113.0     214.800  2011-12-11              2
# 541893  581586.0  2011-12-09    13113.0      70.800  2011-12-11              2
#
# ...

# %%
df_uknew2.drop_duplicates(inplace = True)

# %%
df_uknew2
# Out:
#        InvoiceNo InvoiceDate CustomerID  TotalPrice    Ref_Date  last_purchase
# 0       536365.0  2010-12-01    17850.0      15.300  2011-12-11            375
# 1       536365.0  2010-12-01    17850.0      20.340  2011-12-11            375
# 2       536365.0  2010-12-01    17850.0      22.000  2011-12-11            375
# 5       536365.0  2010-12-01    17850.0      15.300  2011-12-11            375
# 6       536365.0  2010-12-01    17850.0      25.500  2011-12-11            375
# ...          ...         ...        ...         ...         ...            ...
# 541888  581585.0  2011-12-09    15804.0      11.400  2011-12-11              2
# 541890  581586.0  2011-12-09    13113.0      23.600  2011-12-11              2
# 541891  581586.0  2011-12-09    13113.0      30.000  2011-12-11              2
# 541892  581586.0  2011-12-09    13113.0     214.800  2011-12-11              2
# 541893  581586.0  2011-12-09    13113.0      70.800  2011-12-11              2
#
# ...

# %% [markdown]
# 2. Calculate the frequency of purchases ?? (yeni formul)

# %%
rfmtablef = df_uknew2.groupby('CustomerID').agg({'InvoiceNo': "nunique" }).reset_index().rename(columns = {'InvoiceNo':'frequency'})

# %%
rfmtablef
# Out:
#      CustomerID  frequency
# 0       12346.0          1
# 1       12747.0         89
# 2       12748.0       2721
# 3       12749.0        108
# 4       12820.0         35
# ...         ...        ...
# 3911    18280.0          8
# 3912    18281.0          4
# 3913    18282.0         11
# 3914    18283.0        233
# 3915    18287.0         42
#
# [3916 rows x 2 columns]

# %% [markdown]
# 3. Plot RFM distributions

# %%
plt.figure(figsize=(12,10))
sns.distplot(rfmtablef['frequency'])

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
rfmtablem = df_uknew2.groupby('CustomerID').agg({'TotalPrice': lambda x: x.sum()}).reset_index().rename(columns = {'TotalPrice':'monetary'})

# %%
rfmtablem
# Out:
#      CustomerID  monetary
# 0       12346.0 77183.600
# 1       12747.0  3820.290
# 2       12748.0 23967.150
# 3       12749.0  2416.070
# 4       12820.0   578.160
# ...         ...       ...
# 3911    18280.0   147.900
# 3912    18281.0    53.790
# 3913    18282.0   165.300
# 3914    18283.0   860.230
# 3915    18287.0  1195.760
#
# [3916 rows x 2 columns]

# %% [markdown]
# 2. Plot RFM distributions

# %%
plt.figure(figsize=(12,10))
sns.distplot(rfmtablem['monetary'])

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
dfs = [rfmtable, rfmtablef, rfmtablem]

# %%
from functools import reduce
RfmTable = reduce(lambda l, r: pd.merge(l, r, on='CustomerID', how='inner'), dfs)

# %%
RfmTable
# Out:
#      CustomerID  recency  frequency  monetary
# 0       12346.0      327          1 77183.600
# 1       12747.0        4         89  3820.290
# 2       12748.0        2       2721 23967.150
# 3       12749.0        5        108  2416.070
# 4       12820.0        5         35   578.160
# ...         ...      ...        ...       ...
# 3911    18280.0      279          8   147.900
# 3912    18281.0      182          4    53.790
# 3913    18282.0        9         11   165.300
# 3914    18283.0        5        233   860.230
# 3915    18287.0       44         42  1195.760
#
# [3916 rows x 4 columns]

# %%
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.distplot(RfmTable['recency'])
# Plot distribution of F
plt.subplot(3, 1, 2); sns.distplot(RfmTable['frequency'])
# Plot distribution of M
plt.subplot(3, 1, 3); sns.distplot(RfmTable['monetary'])
# Show the plot
plt.show()

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
# rfm['r_quartile'] = pd.qcut(rfm['recency'], 4, ['1','2','3','4'])
# rfm['f_quartile'] = pd.qcut(rfm['frequency'], 4, ['4','3','2','1'])
# rfm['m_quartile'] = pd.qcut(rfm['monetary'], 4, ['4','3','2','1'])

# %%
quantiles = RfmTable.quantile(q=[0.25,0.5,0.75])

# %%
quantiles
# Out:
#        recency  frequency  monetary
# 0.250   19.000     11.000   209.692
# 0.500   52.000     27.000   465.860
# 0.750  145.000     62.000  1104.405

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
rfmSegmentation = RfmTable

# %%
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def RClass(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1
    
# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)
def FMClass(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
rfmSegmentation
# Out:
#      CustomerID  recency  frequency  monetary
# 0       12346.0      327          1 77183.600
# 1       12747.0        4         89  3820.290
# 2       12748.0        2       2721 23967.150
# 3       12749.0        5        108  2416.070
# 4       12820.0        5         35   578.160
# ...         ...      ...        ...       ...
# 3911    18280.0      279          8   147.900
# 3912    18281.0      182          4    53.790
# 3913    18282.0        9         11   165.300
# 3914    18283.0        5        233   860.230
# 3915    18287.0       44         42  1195.760
#
# [3916 rows x 4 columns]

# %%
rfmSegmentation['R_Quartile'] = rfmSegmentation['recency'].apply(RClass, args=('recency',quantiles,))
rfmSegmentation['F_Quartile'] = rfmSegmentation['frequency'].apply(FMClass, args=('frequency',quantiles,))
rfmSegmentation['M_Quartile'] = rfmSegmentation['monetary'].apply(FMClass, args=('monetary',quantiles,))

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
rfmSegmentation['RFMClass'] = rfmSegmentation.R_Quartile.map(str) + rfmSegmentation.F_Quartile.map(str) + rfmSegmentation.M_Quartile.map(str)

# %%
rfmSegmentation
# Out:
#      CustomerID  recency  frequency  monetary  R_Quartile  F_Quartile  \
# 0       12346.0      327          1 77183.600           1           1
# 1       12747.0        4         89  3820.290           4           4
# 2       12748.0        2       2721 23967.150           4           4
# 3       12749.0        5        108  2416.070           4           4
# 4       12820.0        5         35   578.160           4           3
# ...         ...      ...        ...       ...         ...         ...
# 3911    18280.0      279          8   147.900           1           1
# 3912    18281.0      182          4    53.790           1           1
# 3913    18282.0        9         11   165.300           4           1
# 3914    18283.0        5        233   860.230           4           4
# 3915    18287.0       44         42  1195.760           3           3
#
#       M_Quartile RFMClass
# 0              4      114
# 1              4      444
# 2              4      444
# ...

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
rfmSegmentation.RFMClass.value_counts()
# Out:
# 444    416
# 111    336
# 344    184
# 122    181
# 211    166
# 222    152
# 333    151
# 433    136
# 233    133
# 121    115
# 322    111
# 311    100
# 244     89
# 112     88
# 223     78
# 343     78
# 443     77
# 434     73
# 332     73
# 212     71
# 422     63
# 321     59
# 232     57
# 334     56
# 133     54
# 411     54
# 323     52
# 234     51
# 221     51
# 132     51
# 123     44
# 423     39
# 432     37
# 213     36
# 243     33
# 312     31
# 113     27
# 421     23
# 131     22
# 342     20
# 224     19
# 143     19
# 412     18
# 331     18
# 424     18
# 431     18
# 231     17
# 144     16
# 442     14
# 324     12
# 313     12
# 314     10
# 214     10
# 413     10
# 242      9
# 114      9
# 414      6
# 134      5
# 124      5
# 142      3
# Name: RFMClass, dtype: int64

# %% [markdown]
# ![image.png](attachment:13ad0876-18a9-46dd-9cd5-4d03cddaa00d.png)

# %%
def rfm_level(df):
    if df['RFMClass'] == '444':
        return "Champions"
    if df['RFMClass'] in ["334","342","343","344","433","434","443"]:
        return 'Loyal'
    elif df['RFMClass'] in ["411","332","333","313","341","412","413","414","431","432","441","442","421","422","423","424"]:
        return 'Promising'
    elif df['RFMClass'] in ["212","213","214","231","232","233","241","314","321","322","323","324","311","312","331"]:
        return 'Needing Attention'
    elif df['RFMClass'] in ["111","141","112","113","114","131","132","133","142","124","123","122","121","224","223","222","221","211"]:
        return 'At Risk'
    elif df['RFMClass'] in ["134","143","144","234","242","243","244"]:
        return 'Cant Lose'

# %%
# Create a new variable RFM_Level
rfmSegmentation['RFM_Level'] = rfmSegmentation.apply(rfm_level, axis=1)
# Print the header with top 5 rows to the console
rfmSegmentation.head()
# Out:
#   CustomerID  recency  frequency  monetary  R_Quartile  F_Quartile  \
# 0    12346.0      327          1 77183.600           1           1
# 1    12747.0        4         89  3820.290           4           4
# 2    12748.0        2       2721 23967.150           4           4
# 3    12749.0        5        108  2416.070           4           4
# 4    12820.0        5         35   578.160           4           3
#
#    M_Quartile RFMClass  RFM_Sum  RFM_Level
# 0           4      114        6    At Risk
# 1           4      444       12  Champions
# 2           4      444       12  Champions
# 3           4      444       12  Champions
# 4           3      433       10      Loyal

# %%
rfmSegmentation['RFM_Level'].value_counts().sum()
# Out:
# 3916

# %%
rfmSegmentation["RFM_Level"].value_counts()
# Out:
# At Risk              1401
# Needing Attention     717
# Loyal                 624
# Promising             536
# Champions             416
# Cant Lose             222
# Name: RFM_Level, dtype: int64

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
rfm_level_agg = rfmSegmentation.groupby('RFM_Level').agg({
    'recency': 'mean',
    'frequency': 'mean',
    'monetary': ['mean', 'count']}).round(1)
# Print the aggregated dataset
print(rfm_level_agg)
# Out:
#                   recency frequency monetary
#                      mean      mean     mean count
# RFM_Level
# At Risk           195.900    14.900  420.700  1401
# Cant Lose         103.000    83.800 1648.500   222
# Champions           8.700   212.400 6133.500   416
# Loyal              22.400    87.500 1713.000   624
# Needing Attention  58.200    21.300  464.600   717
# Promising          20.500    30.200  865.700   536

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
# rfm_level_agg.columns = rfm_level_agg.columns.droplevel()
rfm_level_agg.columns = ['RecencyMean','FrequencyMean','MonetaryMean', 'Count']

#Create our plot and resize it.
fig = plt.gcf()
ax = fig.add_subplot()
colors=sns.color_palette("tab20")
fig.set_size_inches(16, 9)
squarify.plot(sizes=rfm_level_agg['Count'], 
              label=['At Risk',
                     'Champions',
                     "Can't Lose",
                     "Loyal",
                     'Needs Attention',
                     'Recent', 
                     'Promising'], color=colors, alpha=0.8 , pad=0.5, text_kwargs={'fontsize': 18} )
plt.title("RFM Segments", fontsize=24, fontweight="bold", pad=5)
plt.axis('off')
plt.show()

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales) we can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %%
#Değerlerin içeriklerini inceliyoruz.
rfmSegmentation.groupby('RFMClass').agg({
'recency': ['mean','min','max','count'],
'frequency': ['mean','min','max'],
'monetary': ['mean','min','max','count'] }).round(1)
# Out:
#          recency                 frequency            monetary           \
#             mean  min  max count      mean min   max      mean      min
# RFMClass
# 111      260.900  147  375   336     5.900   1    11   117.600    3.800
# 112      259.100  149  375    88     7.100   1    11   288.300  211.500
# 113      242.700  152  368    27     5.400   1    11   686.700  470.700
# 114      270.100  184  374     9     3.200   1    10 19358.000 1126.000
# 121      262.500  147  375   115    17.800  12    27   142.700   37.100
# 122      237.400  147  375   181    17.700  12    27   307.700  210.100
# 123      227.500  153  375    44    20.100  12    27   635.700  465.900
# 124      228.800  157  360     5    19.000  15    23  2613.400 1246.200
# 131      276.700  151  375    22    34.400  28    50   167.500  103.900
# 132      227.700  146  375    51    41.200  28    62   327.100  209.800
# 133      217.600  150  356    54    38.700  28    60   688.000  466.700
# ...

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(x ="RFM_Level", data = rfmSegmentation)
plt.title('RFM Segments')
ax.bar_label(ax.containers[0]);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-8add24ab8d97> in <module>()
#       2 ax = sns.countplot(x ="RFM_Level", data = rfmSegmentation)
#       3 plt.title('RFM Segments')
# ----> 4 ax.bar_label(ax.containers[0]);
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [raw]
# Advantages:
# RFM can be applied to different types of businesses
# It can lead to reduced marketing costs by helping you target the right customers
# The data can be a good source for loyalty programs
# It can be combined with other analytics tools for better insights
# It can help you to identify your best customers
#
# Disadvantages:
# Calculating RFM scores can be challenging
# RFM analysis depends on historic data, and not future prospects
# This analysis might not be suitable if you only sell one product

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into 6 different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
rfm =rfmSegmentation.copy()

# %%
rfm = rfm.reset_index()

# %%
rfm.head()
# Out:
#    index CustomerID  recency  frequency  monetary  R_Quartile  F_Quartile  \
# 0      0    12346.0      327          1 77183.600           1           1
# 1      1    12747.0        4         89  3820.290           4           4
# 2      2    12748.0        2       2721 23967.150           4           4
# 3      3    12749.0        5        108  2416.070           4           4
# 4      4    12820.0        5         35   578.160           4           3
#
#    M_Quartile RFMClass  RFM_Sum  RFM_Level
# 0           4      114        6    At Risk
# 1           4      444       12  Champions
# 2           4      444       12  Champions
# 3           4      444       12  Champions
# 4           3      433       10      Loyal

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3916 entries, 0 to 3915
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       3916 non-null   int64
#  1   CustomerID  3916 non-null   object
#  2   recency     3916 non-null   int64
#  3   frequency   3916 non-null   int64
#  4   monetary    3916 non-null   float64
#  5   R_Quartile  3916 non-null   int64
#  6   F_Quartile  3916 non-null   int64
#  7   M_Quartile  3916 non-null   int64
#  8   RFMClass    3916 non-null   object
#  9   RFM_Sum     3916 non-null   int64
#  10  RFM_Level   3916 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 336.7+ KB

# %%
rfm_kmeans = rfm[["recency","frequency","monetary"]]

# %%
rfm_kmeans.head()
# Out:
#    recency  frequency  monetary
# 0      327          1 77183.600
# 1        4         89  3820.290
# 2        2       2721 23967.150
# 3        5        108  2416.070
# 4        5         35   578.160

# %%
rfm_kmeans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3916 entries, 0 to 3915
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   recency    3916 non-null   int64
#  1   frequency  3916 non-null   int64
#  2   monetary   3916 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 91.9 KB

# %%
rfm_kmeans.describe().T
# Out:
#              count     mean      std   min     25%     50%      75%        max
# recency   3916.000   93.887   99.718 2.000  19.000  52.000  145.000    375.000
# frequency 3916.000   54.629  116.060 1.000  11.000  27.000   62.000   4058.000
# monetary  3916.000 1372.041 5968.098 3.750 209.692 465.860 1104.405 173369.020

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
plt.rcParams["figure.figsize"] = (10,6)

# %%
sns.heatmap(rfm_kmeans.corr(), annot=True);

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(rfm_kmeans)
plt.show()

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. You can use the logarithm method to normalize the values in a column.

# %%
log_r = np.log(rfm_kmeans['recency']+0.1)          #can't take log(0) and so add a small number
log_f = np.log(rfm_kmeans['frequency'])
log_m = np.log(rfm_kmeans['monetary']+0.1)

# %%
log_rfm = pd.DataFrame({'recency':log_r, 'frequency' : log_f, "monetary" : log_m })

# %%
log_rfm.head()
# Out:
#    recency  frequency  monetary
# 0    5.790      0.000    11.254
# 1    1.411      4.489     8.248
# 2    0.742      7.909    10.084
# 3    1.629      4.682     7.790
# 4    1.629      3.555     6.360

# %% [markdown]
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
sns.pairplot(log_rfm)
plt.show()

# %%
sns.heatmap(log_rfm.corr(), annot=True);

# %%
X = log_rfm.copy()

# %%
from sklearn.cluster import KMeans

# %%
K_means_model = KMeans(n_clusters=5, random_state=42)

# %%
K_means_model.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
K_means_model.fit_predict(X)
# Out:
# array([0, 3, 3, ..., 2, 3, 1], dtype=int32)

# %%
# !pip install pyclustertend

# %%
from pyclustertend import hopkins

# %%
X.shape
# Out:
# (3916, 3)

# %%
hopkins(X, X.shape[0])
# Out:
# 0.09948277757781519

# %% [markdown]
# The score shows taht our data is randomly distributed and can be clustered.

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
ssd = []

K = range(2,10)                                          # k icin aralik.

for k in K:
    model = KMeans(init='k-means++',n_clusters =k, random_state=42)
    model.fit(X)                                         # Her yeni k sayisina gore modeli egit.
    ssd.append(model.inertia_)

# %%
plt.plot(K, ssd, "bo-")
plt.xlabel("Different k values")
plt.ylabel("inertia-error") 
plt.title("elbow method")
# Out:
# Text(0.5, 1.0, 'elbow method')

# %%
df_diff =pd.DataFrame(-pd.Series(ssd).diff()).rename(index = lambda x : x+1)
df_diff
# Out:
#          0
# 1      NaN
# 2 2147.783
# 3 1327.070
# 4  863.615
# 5  651.284
# 6  437.956
# 7  335.020
# 8  274.456

# %%
from yellowbrick.cluster import KElbowVisualizer

model_ = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_, k=(2,9))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.show();

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(X, K_means_model.fit_predict(X))
# Out:
# 0.27457290691534925

# %%
range_n_clusters = range(2,9)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(init='k-means++',n_clusters=num_clusters, random_state=42)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.3993735147277056
# For n_clusters=3, the silhouette score is 0.3007177380706536
# For n_clusters=4, the silhouette score is 0.305222224369744
# For n_clusters=5, the silhouette score is 0.27457290691534925
# For n_clusters=6, the silhouette score is 0.27591226089210086
# For n_clusters=7, the silhouette score is 0.2706222317139892
# For n_clusters=8, the silhouette score is 0.2681998328322631

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model3 = KMeans(n_clusters=4, random_state=42)
visualizer = SilhouetteVisualizer(model3)

visualizer.fit(X)    # Fit the data to the visualizer
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
model = KMeans(n_clusters =4, random_state=42)
model.fit_predict(X)
# Out:
# array([1, 2, 2, ..., 0, 2, 1], dtype=int32)

# %%
X["predicted_clusters"] = model.fit_predict(X)

# %%
rfm_level = rfm.RFM_Level

# %%
rfm_level
# Out:
# 0         At Risk
# 1       Champions
# 2       Champions
# 3       Champions
# 4           Loyal
#           ...
# 3911      At Risk
# 3912      At Risk
# 3913    Promising
# 3914        Loyal
# 3915        Loyal
# Name: RFM_Level, Length: 3916, dtype: object

# %%
rfm_level.to_csv("rfm_level.csv", index=False)

# %%
levels = pd.read_csv("rfm_level.csv")
levels
# Out:
#       RFM_Level
# 0       At Risk
# 1     Champions
# 2     Champions
# 3     Champions
# 4         Loyal
# ...         ...
# 3911    At Risk
# 3912    At Risk
# 3913  Promising
# 3914      Loyal
# 3915      Loyal
#
# [3916 rows x 1 columns]

# %%
X["levels"] = levels

# %%
X.head()
# Out:
#    recency  frequency  monetary  predicted_clusters     levels
# 0    5.790      0.000    11.254                   1    At Risk
# 1    1.411      4.489     8.248                   2  Champions
# 2    0.742      7.909    10.084                   2  Champions
# 3    1.629      4.682     7.790                   2  Champions
# 4    1.629      3.555     6.360                   0      Loyal

# %%
ct = pd.crosstab(X.predicted_clusters, X.levels)
ct
# Out:
# levels              At Risk  Cant Lose  Champions  Loyal  Needing Attention  \
# predicted_clusters
# 0                        63          0          0     54                347
# 1                       282        222          0    216                242
# 2                         0          0        416    354                  0
# 3                      1056          0          0      0                128
#
# levels              Promising
# predicted_clusters
# 0                         349
# 1                         161
# 2                          25
# 3                           1

# %%
from sklearn.metrics import adjusted_rand_score

# %%
adjusted_rand_score(X.levels, X.predicted_clusters)
# Out:
# 0.381568076231908

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
centers = model.cluster_centers_
centers
# Out:
# array([[3.06747722, 2.80070626, 5.60915269],
#        [4.21068692, 3.77902506, 6.70860985],
#        [2.23400781, 4.72872491, 7.72822304],
#        [5.16335434, 2.09027669, 5.14257307]])

# %%
centers[:,0]
# Out:
# array([3.06747722, 4.21068692, 2.23400781, 5.16335434])

# %%
centers[:,1] # centers of sepal_width feature
# Out:
# array([2.80070626, 3.77902506, 4.72872491, 2.09027669])

# %%
plt.scatter(centers[:,0], centers[:,1], c = "black")

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %% [markdown]
# ### iv. Assign the Label

# %%
rfm.head()
# Out:
#    index CustomerID  recency  frequency  monetary  R_Quartile  F_Quartile  \
# 0      0    12346.0      327          1 77183.600           1           1
# 1      1    12747.0        4         89  3820.290           4           4
# 2      2    12748.0        2       2721 23967.150           4           4
# 3      3    12749.0        5        108  2416.070           4           4
# 4      4    12820.0        5         35   578.160           4           3
#
#    M_Quartile RFMClass  RFM_Sum  RFM_Level
# 0           4      114        6    At Risk
# 1           4      444       12  Champions
# 2           4      444       12  Champions
# 3           4      444       12  Champions
# 4           3      433       10      Loyal

# %%
rfm["frequency_score"] = rfm["F_Quartile"].astype(int)
rfm["recency_score"] = rfm["R_Quartile"].astype(int)
rfm["monetary_score"] = rfm["M_Quartile"].astype(int)

# %% [raw]
# Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
#
# Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.

# %%
def rfm_level(rfm):
    if ((rfm["frequency_score"] == 4) and (rfm["recency_score"] == 4) and (rfm["monetary_score"] >= 3)):
        return "Best Customers"
    elif ((rfm["recency_score"] <= 1) and (rfm["frequency_score"] >= 2) and (rfm["frequency_score"] < 4) and (rfm["monetary_score"] < 3)):
        return 'Passer Customers'
    else:
        return 'Almost Lost'
    #else:
    #    return 'Require Activation'
# Create a new variable RFM_Level
rfm['Cluster'] = rfm.apply(rfm_level, axis=1)
# Print the header with top 5 rows to the console
rfm.head()
# Out:
#    index CustomerID  recency  frequency  monetary  R_Quartile  F_Quartile  \
# 0      0    12346.0      327          1 77183.600           1           1
# 1      1    12747.0        4         89  3820.290           4           4
# 2      2    12748.0        2       2721 23967.150           4           4
# 3      3    12749.0        5        108  2416.070           4           4
# 4      4    12820.0        5         35   578.160           4           3
#
#    M_Quartile RFMClass  RFM_Sum  RFM_Level  frequency_score  recency_score  \
# 0           4      114        6    At Risk                1              1
# 1           4      444       12  Champions                4              4
# 2           4      444       12  Champions                4              4
# 3           4      444       12  Champions                4              4
# 4           3      433       10      Loyal                3              4
#
#    monetary_score         Cluster
# 0               4     Almost Lost
# ...

# %%
rfm.Cluster.unique()
# Out:
# array(['Almost Lost', 'Best Customers', 'Passer Customers'], dtype=object)

# %%
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3916 entries, 0 to 3915
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            3916 non-null   int64
#  1   CustomerID       3916 non-null   object
#  2   recency          3916 non-null   int64
#  3   frequency        3916 non-null   int64
#  4   monetary         3916 non-null   float64
#  5   R_Quartile       3916 non-null   int64
#  6   F_Quartile       3916 non-null   int64
#  7   M_Quartile       3916 non-null   int64
#  8   RFMClass         3916 non-null   object
#  9   RFM_Sum          3916 non-null   int64
#  10  RFM_Level        3916 non-null   object
#  11  frequency_score  3916 non-null   int64
#  12  recency_score    3916 non-null   int64
#  13  monetary_score   3916 non-null   int64
#  14  Cluster          3916 non-null   object
# dtypes: float64(1), int64(10), object(4)
# memory usage: 459.0+ KB

# %%
rfm_cluster = rfm["Cluster"]
rfm_cluster
# Out:
# 0          Almost Lost
# 1       Best Customers
# 2       Best Customers
# 3       Best Customers
# 4          Almost Lost
#              ...
# 3911       Almost Lost
# 3912       Almost Lost
# 3913       Almost Lost
# 3914    Best Customers
# 3915       Almost Lost
# Name: Cluster, Length: 3916, dtype: object

# %%
rfm_cluster.to_csv("rfm_cluster.csv", index=False)

# %%
X.head()
# Out:
#    recency  frequency  monetary  predicted_clusters     levels
# 0    5.790      0.000    11.254                   1    At Risk
# 1    1.411      4.489     8.248                   2  Champions
# 2    0.742      7.909    10.084                   2  Champions
# 3    1.629      4.682     7.790                   2  Champions
# 4    1.629      3.555     6.360                   0      Loyal

# %%
X2 = X[["recency", "frequency", "monetary"]]
X2.head()
# Out:
#    recency  frequency  monetary
# 0    5.790      0.000    11.254
# 1    1.411      4.489     8.248
# 2    0.742      7.909    10.084
# 3    1.629      4.682     7.790
# 4    1.629      3.555     6.360

# %%
model2 = KMeans(n_clusters =3, random_state=42)
model2.fit_predict(X2)
# Out:
# array([1, 2, 2, ..., 1, 2, 1], dtype=int32)

# %%
X2["predicted_clusters"] = model2.fit_predict(X2)

# %%
X2.head()
# Out:
#    recency  frequency  monetary  predicted_clusters
# 0    5.790      0.000    11.254                   1
# 1    1.411      4.489     8.248                   2
# 2    0.742      7.909    10.084                   2
# 3    1.629      4.682     7.790                   2
# 4    1.629      3.555     6.360                   2

# %%
cluster = pd.read_csv("rfm_cluster.csv")
cluster
# Out:
#              Cluster
# 0        Almost Lost
# 1     Best Customers
# 2     Best Customers
# 3     Best Customers
# 4        Almost Lost
# ...              ...
# 3911     Almost Lost
# 3912     Almost Lost
# 3913     Almost Lost
# 3914  Best Customers
# 3915     Almost Lost
#
# [3916 rows x 1 columns]

# %%
X2["cluster"] = cluster

# %%
X2.head()
# Out:
#    recency  frequency  monetary  predicted_clusters         cluster
# 0    5.790      0.000    11.254                   1     Almost Lost
# 1    1.411      4.489     8.248                   2  Best Customers
# 2    0.742      7.909    10.084                   2  Best Customers
# 3    1.629      4.682     7.790                   2  Best Customers
# 4    1.629      3.555     6.360                   2     Almost Lost

# %%
X_labels = X2.cluster.map({"Passer Customers":0, "Best Customers":1,"Almost Lost":2})
X_labels
# Out:
# 0       2
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 3911    2
# 3912    2
# 3913    2
# 3914    1
# 3915    2
# Name: cluster, Length: 3916, dtype: int64

# %%
plt.figure(figsize = (20,6))

plt.subplot(121)
plt.scatter(X2["frequency"], X2["monetary"], c = X_labels, cmap = "viridis", alpha=0.7)  # alpha --> Saydamlik. Ust uste binen degerlerin gorunmesi icin.
plt.title("Actual")

plt.subplot(122)
plt.scatter(X2["frequency"], X2["monetary"], c = X2.predicted_clusters, cmap = "viridis", alpha=0.7)
plt.title("Predicted");

# %%
fig = plt.figure(figsize=(20,6))
ax1 = fig.add_subplot(121,projection='3d')
res1 = ax1.scatter3D(X['recency'], X['frequency'], X['monetary'], c=X_labels, cmap = "viridis", alpha=0.7)
ax1.set_xlabel('Recency')
ax1.set_ylabel('Frequency')
ax1.set_zlabel('Monetary')
ax1.set_title('Actual')
ax2 = fig.add_subplot(122,projection='3d')
res2 = ax2.scatter3D(X["recency"], X['frequency'], X["monetary"], c = X2.predicted_clusters, cmap = "viridis",
                     alpha=0.7)
ax2.set_xlabel('Recency')
ax2.set_ylabel('Frequency')
ax2.set_zlabel('Monetary')
ax2.set_title('Predicted')
plt.show()

# %%
adjusted_rand_score(X2.cluster, X2.predicted_clusters)
# Out:
# 0.18080607038979296

# %%
pd.crosstab(X2.predicted_clusters, X2.cluster)
# Out:
# cluster             Almost Lost  Best Customers  Passer Customers
# predicted_clusters
# 0                          1024               0               337
# 1                          1607               8                32
# 2                           423             485                 0

# %% [markdown]
# Tableau: https://public.tableau.com/app/profile/muhammet.mu.lu/viz/CustomerSegmentationandRFMAnalysis/CustomerSegmentationandRFMAnalysis

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# **Conclusion**
#
# - Cluster 0 : The first cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)
#
# - Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
# - Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                InvoiceDate  UnitPrice CustomerID  TotalPrice
# ...

# %%
import datetime as dt
def get_date(date):
  return dt.datetime(date.year, date.month, 1)

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %%
df_uk['InvoiceMonth'] = df_uk['InvoiceDate'].apply(get_date)

# %%
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                InvoiceDate  UnitPrice CustomerID  TotalPrice InvoiceMonth
# ...

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %%
def get_date_int(date_column):
    year = date_column.dt.year
    month = date_column.dt.month
    return year, month

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 seperate series for each of the two columns

# %%
df_uk['CohortMonth'] = df_uk.groupby('CustomerID')['InvoiceMonth'].transform('min')
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                InvoiceDate  UnitPrice CustomerID  TotalPrice InvoiceMonth  \
# ...

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %%
invoice_year,invoice_month = get_date_int(df_uk['InvoiceMonth'])
cohort_year,cohort_month = get_date_int(df_uk['CohortMonth'])

year_diff = invoice_year - cohort_year 
month_diff = invoice_month - cohort_month 

df_uk['CohortIndex'] = year_diff * 12 + month_diff + 1 
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0       536365.0    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1       536365.0   71053.0                  WHITE METAL LANTERN     6.000
# 2       536365.0    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3       536365.0    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4       536365.0    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...          ...       ...                                  ...       ...
# 541889  581585.0   22466.0       FAIRY TALE COTTAGE NIGHT LIGHT    12.000
# 541890  581586.0   22061.0  LARGE CAKE STAND  HANGING STRAWBERY     8.000
# 541891  581586.0   23275.0     SET OF 3 HANGING OWLS OLLIE BEAK    24.000
# 541892  581586.0   21217.0        RED RETROSPOT ROUND CAKE TINS    24.000
# 541893  581586.0   20685.0                DOORMAT RED RETROSPOT    10.000
#
#                InvoiceDate  UnitPrice CustomerID  TotalPrice InvoiceMonth  \
# ...

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
#Count monthly active customers from each cohort
grouping = df_uk.groupby(['CohortMonth', 'CohortIndex'])
cohort_1 = grouping['CustomerID'].apply(pd.Series.nunique)
# Return number of unique elements in the object.
cohort_1 = cohort_1.reset_index()
cohort_counts = cohort_1.pivot(index='CohortMonth',columns='CohortIndex',values='CustomerID')
cohort_counts
# Out:
# CohortIndex      1       2       3       4       5       6       7       8   \
# CohortMonth
# 2010-12-01  814.000 288.000 263.000 303.000 293.000 323.000 290.000 277.000
# 2011-01-01  357.000  75.000  93.000  84.000 117.000  99.000  90.000  86.000
# 2011-02-01  340.000  64.000  66.000  98.000  98.000  85.000  88.000  94.000
# 2011-03-01  419.000  64.000 109.000  83.000  94.000  69.000 111.000  96.000
# 2011-04-01  277.000  58.000  56.000  60.000  56.000  61.000  61.000  73.000
# 2011-05-01  256.000  48.000  44.000  44.000  53.000  58.000  68.000  23.000
# 2011-06-01  214.000  38.000  31.000  51.000  51.000  69.000  21.000     NaN
# 2011-07-01  168.000  30.000  33.000  39.000  47.000  18.000     NaN     NaN
# 2011-08-01  141.000  31.000  32.000  34.000  17.000     NaN     NaN     NaN
# 2011-09-01  276.000  63.000  83.000  32.000     NaN     NaN     NaN     NaN
# 2011-10-01  323.000  78.000  36.000     NaN     NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# #### Retention Rate

# %%
# Retention table
cohort_size = cohort_counts.iloc[:,0]
retention = cohort_counts.divide(cohort_size,axis=0) #axis=0 to ensure the divide along the row axis 
retention.round(3) * 100 #to show the number as percentage
# Out:
# CohortIndex      1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2010-12-01  100.000 35.400 32.300 37.200 36.000 39.700 35.600 34.000 35.400
# 2011-01-01  100.000 21.000 26.100 23.500 32.800 27.700 25.200 24.100 29.700
# 2011-02-01  100.000 18.800 19.400 28.800 28.800 25.000 25.900 27.600 26.500
# 2011-03-01  100.000 15.300 26.000 19.800 22.400 16.500 26.500 22.900 28.400
# 2011-04-01  100.000 20.900 20.200 21.700 20.200 22.000 22.000 26.400  7.200
# 2011-05-01  100.000 18.800 17.200 17.200 20.700 22.700 26.600  9.000    NaN
# 2011-06-01  100.000 17.800 14.500 23.800 23.800 32.200  9.800    NaN    NaN
# 2011-07-01  100.000 17.900 19.600 23.200 28.000 10.700    NaN    NaN    NaN
# 2011-08-01  100.000 22.000 22.700 24.100 12.100    NaN    NaN    NaN    NaN
# 2011-09-01  100.000 22.800 30.100 11.600    NaN    NaN    NaN    NaN    NaN
# 2011-10-01  100.000 24.100 11.100    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 8))
plt.title('Retention rates')
sns.heatmap(data=retention,annot = True,fmt = '.1%',vmin = 0.0,vmax = 0.5,cmap="BuPu_r")
plt.show()

# %% [markdown]
# ref: https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d

# %%
# Users which started using the app in first month
# dfu = df_uk[df_uk['CohortIndex']==1]['CustomerID'].unique() 
# df_start = df_uk[(df_uk['CustomerID'].isin(dfu))]
# df_start.head()

# Monthly active users for current year
# monthly_active_curr_year= df_start.groupby(['InvoiceMonth']).nunique()['CustomerID']

# Total Number of active users
monthly_active_users= df_uk.groupby(['InvoiceMonth']).nunique()['CustomerID']

# plot
sns.set(font_scale=1,rc={'figure.figsize':(10, 6)})
sns.set_palette("brg",3)
sns.set_style("ticks")
fig, ax = plt.subplots()
monthly_active_users.plot(ax=ax, linewidth=4, label='Monthly Active users')
# monthly_active_curr_year.plot(ax=ax, linewidth=4, label='Monthly Active users for the year')
plt.xlabel("Months")
plt.ylabel("Monthly Active Users")
plt.title("Monthly Active Users per month for the year")
plt.legend()

# %%
#Function which takes the dataframe and date of cohort as month input
def monthlyRetention(df, date):
  cohort=df[(df['CohortIndex'] == 1) & (df['InvoiceMonth'] == date)]
  
  # num_of_customers is the number of unique customer ids in the 'cohort'
  num_of_customers= cohort['CustomerID'].nunique()
  print("Number of distinct customers on %s:" %date, num_of_customers)

  # list_cohort consists of all the unique customer ids in 'cohort'
  list_cohort= cohort['CustomerID'].unique()
  
  #df_cohort is the df which has same customer ids as in list_cohort
  df_cohort= df[df['CustomerID'].isin(list_cohort)]
  
  #cohort_data calculates the percentage of unique customers who used the app on each day.
  cohort_data = pd.DataFrame((df_cohort.groupby(['InvoiceMonth']).nunique()['CustomerID']/num_of_customers*100).round(2))
  
  return cohort_data

# %%
dates = ['2010-12-01', 
         '2011-03-01',
         '2011-06-01',
         '2011-09-01']

# Average Number of Quantities
monthly_1 = monthlyRetention(df_uk, dates[0])
monthly_2 = monthlyRetention(df_uk, dates[1])
monthly_3 = monthlyRetention(df_uk, dates[2])
monthly_4 = monthlyRetention(df_uk, dates[3])


# plot
sns.set(font_scale=1,rc={'figure.figsize':(10, 6)})
sns.set_palette("brg",3)
sns.set_style("ticks")
fig, ax = plt.subplots()
monthly_1.plot(ax=ax, linewidth=2, label='Monthly Retention')
monthly_2.plot(ax=ax, linewidth=2)
monthly_3.plot(ax=ax, linewidth=2)
monthly_4.plot(ax=ax, linewidth=2)

plt.xlabel("Months")
plt.ylabel("Monthly Retention")
plt.title("Monthly Retention Rate per Month")
plt.legend(title='dates', labels=dates) #, loc='upper left')
# Out:
# Number of distinct customers on 2010-12-01: 814
# Number of distinct customers on 2011-03-01: 419
# Number of distinct customers on 2011-06-01: 214
# Number of distinct customers on 2011-09-01: 276

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
df_uk['Description'].head(100)
# Out:
# 0       WHITE HANGING HEART T-LIGHT HOLDER
# 1                      WHITE METAL LANTERN
# 2           CREAM CUPID HEARTS COAT HANGER
# 3      KNITTED UNION FLAG HOT WATER BOTTLE
# 4           RED WOOLLY HOTTIE WHITE HEART.
# 5             SET 7 BABUSHKA NESTING BOXES
# 6        GLASS STAR FROSTED T-LIGHT HOLDER
# 7                   HAND WARMER UNION JACK
# 8                HAND WARMER RED POLKA DOT
# 9            ASSORTED COLOUR BIRD ORNAMENT
# 10              POPPY'S PLAYHOUSE BEDROOM
# 11               POPPY'S PLAYHOUSE KITCHEN
# 12       FELTCRAFT PRINCESS CHARLOTTE DOLL
# 13                 IVORY KNITTED MUG COSY
# 14      BOX OF 6 ASSORTED COLOUR TEASPOONS
# 15           BOX OF VINTAGE JIGSAW BLOCKS
# 16          BOX OF VINTAGE ALPHABET BLOCKS
# 17                HOME BUILDING BLOCK WORD
# 18                LOVE BUILDING BLOCK WORD
# 19             RECIPE BOX WITH METAL HEART
# 20                     DOORMAT NEW ENGLAND
# 21                JAM MAKING SET WITH JARS
# ...

# %%
#Count monthly active customers from each cohort
cohort_2 = df_uk.groupby(['CohortMonth', 'CohortIndex'])['Quantity'].mean()

# Return number of unique elements in the object.
cohort_2 = cohort_2.reset_index()
cohort_counts = cohort_2.pivot(index='CohortMonth',columns='CohortIndex',values='Quantity')
cohort_counts
# Out:
# CohortIndex     1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12-01  11.370 12.870 13.939 13.881 13.358 13.294 14.283  13.785 16.163
# 2011-01-01  18.093  9.372  9.451 15.112 10.037 10.898 13.560  10.771 10.779
# 2011-02-01  11.056 14.070 15.982 12.217 12.321 11.939 13.938  13.777 10.995
# 2011-03-01   9.700 11.430 13.315 10.091 13.533 12.844 13.090  13.829 11.190
# 2011-04-01  10.071 10.177  9.719 11.941 11.864  8.237  9.844   9.364  7.478
# 2011-05-01  10.658  9.390 14.895 12.800 11.066  8.311 10.822 127.098    NaN
# 2011-06-01   9.560 14.809 11.980 12.715  9.826  8.898  9.364     NaN    NaN
# 2011-07-01  10.157 14.985  6.578  8.113  5.786  6.681    NaN     NaN    NaN
# 2011-08-01   9.400  6.049  5.036  5.919  6.566    NaN    NaN     NaN    NaN
# 2011-09-01  11.930  6.140  7.859  9.006    NaN    NaN    NaN     NaN    NaN
# 2011-10-01   8.717  7.241  8.190    NaN    NaN    NaN    NaN     NaN    NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 8))
plt.title('Quantity Averages')
sns.heatmap(data=cohort_counts,annot = True, vmin = 0.0,vmax = 0.5,cmap="BuPu_r")
plt.show()

# %%
# Average Number of Quantities
monthly_average = df_uk.groupby(['InvoiceMonth']).mean()['Quantity']

# plot
sns.set(font_scale=1,rc={'figure.figsize':(10, 6)})
sns.set_palette("brg",3)
sns.set_style("ticks")
fig, ax = plt.subplots()
monthly_average.plot(ax=ax, linewidth=4, label='Monthly Average')

plt.xlabel("Months")
plt.ylabel("Monthly Average Quantities")
plt.title("Monthly Quantities per month for the year")
plt.legend()

# %%
x = df_uk.groupby(['InvoiceMonth'])['Quantity'].sum() / df_uk.groupby(['InvoiceMonth']).nunique()['CustomerID']   # average_qnt = total_qnt / cust_cnt
# grouping = df_uk.groupby(['CohortMonth', 'CohortIndex'])
# cohort_2 = grouping['InvoiceMonth'])['Quantity'].sum()
x.plot.bar()

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
#Count monthly active customers from each cohort
grouping = df_uk.groupby(['CohortMonth', 'CohortIndex'])
cohort_3 = grouping['TotalPrice'].apply(pd.Series.mean)
# Return number of unique elements in the object.
cohort_3 = cohort_3.reset_index()
cohort_counts = cohort_3.pivot(index='CohortMonth',columns='CohortIndex',values='TotalPrice')
cohort_counts
# Out:
# CohortIndex     1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12-01  21.178 22.452 23.973 23.766 20.219 25.046 25.917  23.862 25.968
# 2011-01-01  26.747 18.020 15.366 28.221 18.479 19.150 24.191  17.672 17.826
# 2011-02-01  17.147 20.043 18.356 19.315 17.554 16.124 21.426  22.637 18.243
# 2011-03-01  16.721 20.170 22.578 17.665 20.557 18.416 20.717  19.460 16.482
# 2011-04-01  16.521 20.082 19.261 18.669 19.085 14.111 14.934  15.302 11.547
# 2011-05-01  18.054 17.001 22.060 21.075 18.731 13.492 16.634 262.148    NaN
# 2011-06-01  22.915 15.255 19.640 16.562 13.340 13.313 12.732     NaN    NaN
# 2011-07-01  14.770 24.679 10.293 12.912  9.300  9.373    NaN     NaN    NaN
# 2011-08-01  15.152 11.957 10.799 13.690 15.210    NaN    NaN     NaN    NaN
# 2011-09-01  17.989 11.496 13.639 13.969    NaN    NaN    NaN     NaN    NaN
# 2011-10-01  13.446 11.134 13.771    NaN    NaN    NaN    NaN     NaN    NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 8))
plt.title('Sales Averages')
sns.heatmap(data=cohort_counts,annot = True, vmin = 0.0,vmax = 0.5,cmap="BuPu_r")
plt.show()

# %%
# Average Number of Sales
monthly_average = df_uk.groupby(['InvoiceMonth']).mean()['TotalPrice']

# plot
sns.set(font_scale=1,rc={'figure.figsize':(10, 6)})
sns.set_palette("brg",3)
sns.set_style("ticks")
fig, ax = plt.subplots()
monthly_average.plot(ax=ax, linewidth=4, label='Monthly Average')

plt.xlabel("Months")
plt.ylabel("Monthly Sales")
plt.title("Monthly Sales per month for the year")
plt.legend()

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [raw]
# rfm_df['RFM_Score'] = 0.15*rfm_df['R_rank_norm']+0.28 * \
#     rfm_df['F_rank_norm']+0.57*rfm_df['M_rank_norm']
# rfm_df['RFM_Score'] *= 0.05
# rfm_df = rfm_df.round(2)
# rfm_df[['CustomerName', 'RFM_Score']].head(7)
#
#
# rfm_df["Customer_segment"] = np.where(rfm_df['RFM_Score'] >
#                                       4.5, "Top Customers",
#                                       (np.where(
#                                         rfm_df['RFM_Score'] > 4,
#                                         "High value Customer",
#                                         (np.where(
#     rfm_df['RFM_Score'] > 3,
#                              "Medium Value Customer",
#                              np.where(rfm_df['RFM_Score'] > 1.6,
#                             'Low Value Customers', 'Lost Customers'))))))
# rfm_df[['CustomerName', 'RFM_Score', 'Customer_segment']].head(20)
#
# --------------------------------------------------------------------------------
#
# champions <- c(444)
# loyal_customers <- c(334, 342, 343, 344, 433, 434, 443)
#
# potential_loyalist <- c(332,333,341,412,413,414,431,432,441,442,421,422,423,424)
# recent_customers <- c(411)
#
# promising <- c(311, 312, 313, 331)
#
# needing_attention <- c(212,213,214,231,232,233,241,314,321,322,323,324)
#
# about_to_sleep <- c(211)
# at_risk <- c(112,113,114,131,132,133,142,124,123,122,121,224,223,222,221)
#
# cant_lose <- c(134,143,144,234,242,243,244)
# hibernating <- c(141)
# lost <- c(111)
#
#
#
# Segment	Scores
# Champions	555, 554, 544, 545, 454, 455, 445
# Loyal	543, 444, 435, 355, 354, 345, 344, 335
# Potential Loyalist	553, 551, 552, 541, 542, 533, 532, 531, 452, 451, 442, 441, 431, 453, 433, 432, 423, 353, 352, 351, 342, 341, 333, 323
# New Customers	512, 511, 422, 421 412, 411, 311
# Promising	525, 524, 523, 522, 521, 515, 514, 513, 425,424, 413,414,415, 315, 314, 313
# Need Attention	535, 534, 443, 434, 343, 334, 325, 324
# About To Sleep	331, 321, 312, 221, 213, 231, 241, 251
# At Risk	255, 254, 245, 244, 253, 252, 243, 242, 235, 234, 225, 224, 153, 152, 145, 143, 142, 135, 134, 133, 125, 124
# Cannot Lose Them	155, 154, 144, 214,215,115, 114, 113
# Hibernating customers	332, 322, 233, 232, 223, 222, 132, 123, 122, 212, 211
# Lost customers	111, 112, 121, 131,141,151
#
#
#
# seg_map = {
#     r'[1-2][1-2]': 'Hibernating',
#     r'[1-2][3-4]': 'At Risk',
#     r'[1-2]4': 'Can\'t Loose',
#     r'3[1-2]': 'About to Sleep',
#     r'33': 'Need Attention',
#     r'[3-4][3-4]': 'Loyal Customers',
#     r'41': 'Promising',
#     r'51': 'New Customers',
#     r'[3-4][2-3]': 'Potential Loyalists',
#     r'5[4-5]': 'Champions'
# }
# ----------------------------------------------
#
# Segment	Description	R	F	M
# Champions	Bought recently, buy often and spend the most	4 - 5	4 - 5	4 - 5
# Loyal Customers	Spend good money. Responsive to promotions	2 - 4	3 - 4	4 - 5
# Potential Loyalist	Recent customers, spent good amount, bought more than once	3 - 5	1 - 3	1 - 3
# New Customers	Bought more recently, but not often	4 - 5	< 2	< 2
# Promising	Recent shoppers, but haven’t spent much	3 - 4	< 2	< 2
# Need Attention	Above average recency, frequency & monetary values	3 - 4	3 - 4	3 - 4
# About To Sleep	Below average recency, frequency & monetary values	2 - 3	< 3	< 3
# At Risk	Spent big money, purchased often but long time ago	< 3	2 - 5	2 - 5
# Can’t Lose Them	Made big purchases and often, but long time ago	< 2	4 - 5	4 - 5
# Hibernating	Low spenders, low frequency, purchased long time ago	2 - 3	2 - 3	2 - 3
# Lost	Lowest recency, frequency & monetary scores	< 2	< 2	< 2
#
# -----------------------------------
#
# def rfm_level(df):
#     if df['RFMClass'] == '444':
#         return 'Best Customers'
#     if df['RFMClass'] == '111':
#         return 'Lost Cheap Customers'
#     if df['R_Quartile'] == 1:
#         return 'Lost Customers'
#     if df['R_Quartile'] == 2:
#         return 'Almost Lost Customers'
#     if df['R_Quartile'] == 3:
#         return 'Almost Lost Customers'
#     if df['M_Quartile'] == 4:
#         return 'Big Spenders'
#     if df['F_Quartile'] == 4:
#         return 'Loyal Customers'
#     if (df['R_Quartile'] > 3) & (df['F_Quartile'] < 2):
#         return 'Focus Group'
#     return 'Customers'
#
#
# def rfm_level(df):
#     if df['RFMClass'] == '444':
#         return 'Best Customers'
#     elif df['RFMClass'] in ['414',"413"] :
#         return 'High-spending New Customers '
#     elif df['RFMClass'] in ['442',"441"]:
#         return 'Lowest-Spending Active Loyal Customers '
#     elif df['RFMClass'] in ['144',"143","134","133","114"]:
#         return 'Churned Best Customers'
#     else:
#         return "Customers"
#
#
# def rfm_level(df):
#     if df['RFMClass'] == '444':
#         return "Champions"
#     elif ((df["R_Quartile"] in [1,2,3,4]) & (df["F_Quartile"]==4) & (df["M_Quartile"] in [1,2,3,4])):
#         return 'Loyal Customers'
#     elif ((df["R_Quartile"] in [1,2,3,4]) & (df["F_Quartile"] in [1,2,3,4]) &  (df["M_Quartile"]==4)):
#         return 'Big Spenders'
#     elif ((df["R_Quartile"] in [1,2,3,4]) & (df["F_Quartile"]==4) &  (df["M_Quartile"]==2))&((df["R_Quartile"] in [1,2,3,4]) & (df["F_Quartile"]==4) &  (df["M_Quartile"]==1)):
#         return 'Big'
#     elif ((df["R_Quartile"]==4) & (df["F_Quartile"]==1) &  (df["M_Quartile"] in [1,2,3,4])):
#         return 'Recent Customers'
#     elif ((df["R_Quartile"]==1) & (df["F_Quartile"]==1) &  (df["M_Quartile"] in [1,2,3,4])):
#         return 'Customers'
#
#
# def categorizer(rfm):
#     if (rfm[0] in ['3', '4']) & (rfm[1] in ['3', '4']) & (rfm[2] in ['3', '4']):
#         rfm = 'Champions'
#
#     elif (rfm[0] in ['2', '3', '4']) & (rfm[1] in ['3', '4']) & (rfm[2] in ['1', '2', '3', '4']):
#         rfm = 'Loyal Customers'
#
#     elif (rfm[0] in ['3', '4']) & (rfm[1] in ['2', '3']) & (rfm[2] in ['1', '2', '3', '4']):
#         rfm = 'Potential Loyalist'
