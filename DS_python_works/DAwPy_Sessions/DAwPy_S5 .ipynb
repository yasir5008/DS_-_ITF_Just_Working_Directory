# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
df3 = pd.DataFrame(np.random.randn(5,4),
                    index = ['A', 'B', 'C', 'D', 'E'],
                    columns = 'W X Y Z'.split() )
df3
# Out:
#           W         X         Y         Z
# A  0.496714 -0.138264  0.647689  1.523030
# B -0.234153 -0.234137  1.579213  0.767435
# C -0.469474  0.542560 -0.463418 -0.465730
# D  0.241962 -1.913280 -1.724918 -0.562288
# E -1.012831  0.314247 -0.908024 -1.412304

# %% [markdown]
# ###RESET INDEX

# %%
df3.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A  0.496714 -0.138264  0.647689  1.523030
# 1     B -0.234153 -0.234137  1.579213  0.767435
# 2     C -0.469474  0.542560 -0.463418 -0.465730
# 3     D  0.241962 -1.913280 -1.724918 -0.562288
# 4     E -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.reset_index(drop =True)
# Out:
#           W         X         Y         Z
# 0  0.496714 -0.138264  0.647689  1.523030
# 1 -0.234153 -0.234137  1.579213  0.767435
# 2 -0.469474  0.542560 -0.463418 -0.465730
# 3  0.241962 -1.913280 -1.724918 -0.562288
# 4 -1.012831  0.314247 -0.908024 -1.412304

# %%
df3
# Out:
#           W         X         Y         Z
# A  0.496714 -0.138264  0.647689  1.523030
# B -0.234153 -0.234137  1.579213  0.767435
# C -0.469474  0.542560 -0.463418 -0.465730
# D  0.241962 -1.913280 -1.724918 -0.562288
# E -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.reset_index(drop=True, inplace=True)

# %%
df3
# Out:
#           W         X         Y         Z
# 0  0.496714 -0.138264  0.647689  1.523030
# 1 -0.234153 -0.234137  1.579213  0.767435
# 2 -0.469474  0.542560 -0.463418 -0.465730
# 3  0.241962 -1.913280 -1.724918 -0.562288
# 4 -1.012831  0.314247 -0.908024 -1.412304

# %%
new_index = np.arange(1000,1005)
new_index
# Out:
# array([1000, 1001, 1002, 1003, 1004])

# %%
df3['new_indez'] = new_index
df3
# Out:
#           W         X         Y         Z  new_index  new_indez
# 0  0.496714 -0.138264  0.647689  1.523030       1000       1000
# 1 -0.234153 -0.234137  1.579213  0.767435       1001       1001
# 2 -0.469474  0.542560 -0.463418 -0.465730       1002       1002
# 3  0.241962 -1.913280 -1.724918 -0.562288       1003       1003
# 4 -1.012831  0.314247 -0.908024 -1.412304       1004       1004

# %%
df3.set_index('new_indez',drop=True, inplace=True)
df3
# Out:
#                   W         X         Y         Z  new_index
# new_indez
# 1000       0.496714 -0.138264  0.647689  1.523030       1000
# 1001      -0.234153 -0.234137  1.579213  0.767435       1001
# 1002      -0.469474  0.542560 -0.463418 -0.465730       1002
# 1003       0.241962 -1.913280 -1.724918 -0.562288       1003
# 1004      -1.012831  0.314247 -0.908024 -1.412304       1004

# %%
df3
# Out:
#                   W         X         Y         Z  new_index
# new_indez
# 1000       0.496714 -0.138264  0.647689  1.523030       1000
# 1001      -0.234153 -0.234137  1.579213  0.767435       1001
# 1002      -0.469474  0.542560 -0.463418 -0.465730       1002
# 1003       0.241962 -1.913280 -1.724918 -0.562288       1003
# 1004      -1.012831  0.314247 -0.908024 -1.412304       1004

# %%
df3.set_index('new_index',drop=True, inplace=True)
df3
# Out:
#                   W         X         Y         Z
# new_index
# 1000       0.496714 -0.138264  0.647689  1.523030
# 1001      -0.234153 -0.234137  1.579213  0.767435
# 1002      -0.469474  0.542560 -0.463418 -0.465730
# 1003       0.241962 -1.913280 -1.724918 -0.562288
# 1004      -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.corr()
# Out:
#           W         X         Y         Z
# W  1.000000 -0.579383  0.162034  0.743211
# X -0.579383  1.000000  0.409461 -0.011964
# Y  0.162034  0.409461  1.000000  0.764853
# Z  0.743211 -0.011964  0.764853  1.000000

# %%
new_idx = "MX MY MZ MW MT".split()

# %%
df3['col1'] = new_idx
df3
# Out:
#                   W         X         Y         Z col1
# new_index
# 1000       0.496714 -0.138264  0.647689  1.523030   MX
# 1001      -0.234153 -0.234137  1.579213  0.767435   MY
# 1002      -0.469474  0.542560 -0.463418 -0.465730   MZ
# 1003       0.241962 -1.913280 -1.724918 -0.562288   MW
# 1004      -1.012831  0.314247 -0.908024 -1.412304   MT

# %%
df3.set_index("col1",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-c2ef021025ff> in <module>
# ----> 1 df3.set_index("col1",inplace=True)
#       2 df3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['col1'] are in the columns"

# %%
df3
# Out:
#              W         X         Y         Z
# col1
# MX    0.496714 -0.138264  0.647689  1.523030
# MY   -0.234153 -0.234137  1.579213  0.767435
# MZ   -0.469474  0.542560 -0.463418 -0.465730
# MW    0.241962 -1.913280 -1.724918 -0.562288
# MT   -1.012831  0.314247 -0.908024 -1.412304

# %%
df3.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df3.columns = ['X1', 'X2', 'x3', 'x4']

# %%
df3
# Out:
#             X1        X2        x3        x4
# col1
# MX    0.496714 -0.138264  0.647689  1.523030
# MY   -0.234153 -0.234137  1.579213  0.767435
# MZ   -0.469474  0.542560 -0.463418 -0.465730
# MW    0.241962 -1.913280 -1.724918 -0.562288
# MT   -1.012831  0.314247 -0.908024 -1.412304
